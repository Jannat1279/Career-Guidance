# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("student_recommendation_10th.csv")

# %%
df.head()
# Out:
#    logical_reasoning  numerical_ability  verbal_ability  spatial_ability  \
# 0                  2                  1               5                1
# 1                  3                  1               4                3
# 2                  3                  2               5                2
# 3                  5                  4               0                3
# 4                  1                  0               4                1
#
#    mechanical_aptitude  stories_writing  computer_interest  math_interest  \
# 0                    2                0                  2              3
# 1                    3                2                  2              2
# 2                    3                1                  2              1
# 3                    4                2                  3              5
# 4                    1                4                  2              1
#
#    interest_in_caring_animals  designing_building  ...  empathy  \
# 0                           0                   3  ...        3
# 1                           0                   3  ...        2
# 2                           1                   3  ...        1
# 3                           2                   4  ...        0
# 4                           0                   5  ...        3
#
#    self_awareness  stress_management  conflict_resolution  confident  \
# 0               0                  1                    4          1
# 1               5                  5                    4          1
# 2               2                  1                    5          1
# 3               2                  2                    0          0
# 4               4                  2                    3          1
#
#    drawing_painting  programming_lang  writing_blogging  sports  \
# 0                 0                 1                 0       1
# 1                 0                 1                 0       0
# 2                 0                 1                 0       1
# 3                 0                 1                 0       1
# 4                 1                 0                 0       0
#
#    recommended_stream
# 0            commerce
# 1            commerce
# 2            commerce
# 3             science
# 4                arts
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   logical_reasoning           3000 non-null   int64
#  1   numerical_ability           3000 non-null   int64
#  2   verbal_ability              3000 non-null   int64
#  3   spatial_ability             3000 non-null   int64
#  4   mechanical_aptitude         3000 non-null   int64
#  5   stories_writing             3000 non-null   int64
#  6   computer_interest           3000 non-null   int64
#  7   math_interest               3000 non-null   int64
#  8   interest_in_caring_animals  3000 non-null   int64
#  9   designing_building          3000 non-null   int64
#  10  leadership                  3000 non-null   int64
#  11  creater                     3000 non-null   int64
#  12  risk_taker                  3000 non-null   int64
#  13  discipline                  3000 non-null   int64
#  14  teamwork                    3000 non-null   int64
#  15  pressure_handling           3000 non-null   int64
#  16  empathy                     3000 non-null   int64
#  17  self_awareness              3000 non-null   int64
#  18  stress_management           3000 non-null   int64
#  19  conflict_resolution         3000 non-null   int64
#  20  confident                   3000 non-null   int64
#  21  drawing_painting            3000 non-null   int64
#  22  programming_lang            3000 non-null   int64
#  23  writing_blogging            3000 non-null   int64
#  24  sports                      3000 non-null   int64
#  25  recommended_stream          3000 non-null   object
# dtypes: int64(25), object(1)
# memory usage: 609.5+ KB

# %%
X = df.drop(columns=["recommended_stream"])
y = df["recommended_stream"]

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y_encoded,test_size=0.2,random_state=42)

# %%
rf=RandomForestClassifier();
pipe=make_pipeline(rf);

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('randomforestclassifier', RandomForestClassifier())])

# %%
y_pred=pipe.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
import pickle
pickle.dump(pipe,open('10th_future_pred.pkl','wb'))

# %%
with open("label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)
